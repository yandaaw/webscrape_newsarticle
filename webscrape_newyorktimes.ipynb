# %% [markdown]
# # **Web Scraping - The New York Times**

# %%
pip install newspaper3k
# Out:
# Requirement already satisfied: newspaper3k in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (0.2.8)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (9.0.0)
# Requirement already satisfied: jieba3k>=0.35.1 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: requests>=2.10.0 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (2.27.1)
# Requirement already satisfied: feedparser>=5.2.1 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (6.0.8)
# Requirement already satisfied: tinysegmenter==0.3 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: nltk>=3.2.1 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (3.7)
# Requirement already satisfied: cssselect>=0.9.2 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (1.1.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (4.11.1)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (6.0)
# Requirement already satisfied: tldextract>=2.0.1 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (3.2.0)
# Requirement already satisfied: lxml>=3.6.0 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from newspaper3k) (4.7.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.3.2)
# Requirement already satisfied: six in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2022.3.15)
# Requirement already satisfied: joblib in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.2.1->newspaper3k) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.64.0)
# Requirement already satisfied: click in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.2.1->newspaper3k) (8.0.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->newspaper3k) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.10.0->newspaper3k) (2021.10.8)
# Requirement already satisfied: requests-file>=1.4 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.6.0)
# Requirement already satisfied: colorama in c:\users\corne\appdata\local\programs\python\python310\lib\site-packages (from click->nltk>=3.2.1->newspaper3k) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

import nltk
from newspaper import Article 
import requests

# %%
import requests  
r = requests.get('https://www.nytimes.com/interactive/2017/06/23/opinion/trumps-lies.html')

from bs4 import BeautifulSoup  
soup = BeautifulSoup(r.text, 'html.parser')  
results = soup.find_all('span', attrs={'class':'short-desc'})

records = []  
for result in results:  
    date = result.find('strong').text[0:-1] + ', 2017'
    lie = result.contents[1][1:-2]
    explanation = result.find('a').text[1:-1]
    url = result.find('a')['href']
    records.append((date, lie, explanation, url))

import pandas as pd  
df = pd.DataFrame(records, columns=['date', 'lie', 'explanation', 'url'])  
df['date'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#           date                                                lie  \
# 0   2017-01-21  I wasn't a fan of Iraq. I didn't want to go in...
# 1   2017-01-21  A reporter for Time magazine — and I have been...
# 2   2017-01-23  Between 3 million and 5 million illegal votes ...
# 3   2017-01-25  Now, the audience was the biggest ever. But th...
# 4   2017-01-25  Take a look at the Pew reports (which show vot...
# ..         ...                                                ...
# 175 2017-10-25      We have trade deficits with almost everybody.
# 176 2017-10-27  Wacky & totally unhinged Tom Steyer, who has b...
# 177 2017-11-01  Again, we're the highest-taxed nation, just ab...
# 178 2017-11-07  When you look at the city with the strongest g...
# 179 2017-11-11  I'd rather have him  – you know, work with him...
#
#                                            explanation  \
# 0     He was for an invasion before he was against it.
# 1    Trump was on the cover 11 times and Nixon appe...
# 2               There's no evidence of illegal voting.
# 3    Official aerial photos show Obama's 2009 inaug...
# 4              The report never mentioned voter fraud.
# ..                                                 ...
# 175  We have trade surpluses with more than 100 cou...
# 176  Steyer has financially supported many winning ...
# 177                                         We're not.
# 178  Several other cities, including New York and L...
# 179  There is no evidence that Democrats "set up" R...
#
#                                                    url
# 0    https://www.buzzfeed.com/andrewkaczynski/in-20...
# 1    http://nation.time.com/2013/11/06/10-things-yo...
# 2    https://www.nytimes.com/2017/01/23/us/politics...
# 3    https://www.nytimes.com/2017/01/21/us/politics...
# 4    https://www.nytimes.com/2017/01/24/us/politics...
# ..                                                 ...
# 175  https://www.bea.gov/newsreleases/international...
# 176  https://www.opensecrets.org/donor-lookup/resul...
# 177  http://www.politifact.com/truth-o-meter/statem...
# 178  http://www.politifact.com/truth-o-meter/statem...
# 179  https://www.nytimes.com/interactive/2017/12/10...
#
# [180 rows x 4 columns]

# %%
# Export data to csv
# df.to_csv('trump_lies.csv', index=False, encoding='utf-8')
